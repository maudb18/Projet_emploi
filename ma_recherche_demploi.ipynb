# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import re


names= ['Intitulé_du_poste', 'Date_de_publication', 'lieu', 'competences', 'Type_de_poste']

fn_data = 'data.json'

df = pd.read_json(fn_data, encoding = 'utf8' )
df.to_csv("data.csv", index=False)

df.head(40)
# Out:
#                                     Intitulé du poste  \
# 0                      [\nData Analyst - Publicité\n]
# 1                              [Data analyst - H/F\n]
# 2                     [Customer Data Analyst (H/F)\n]
# 3                         [Master Data Analyst H/F\n]
# 4                      [Portfolio Data Analyst H/F\n]
# 5               [Data Analyst BO/Qlick Sense (h/f)\n]
# 6                 [Product Data Analyst - BI - H/F\n]
# 7          [Data Analyst / Chef de Projet BI (h/f)\n]
# 8    [Business analyst senior DATA CRM - Paris H/F\n]
# 9   [Data scientist / Analyst and software develop...
# 10   [Data Analyst (H/F) – Mobile Gaming - Gaminho\n]
# 11  [Responsable Analyses et Data Relation Clients...
# 12                           [\nDATA INGENIEUR F/H\n]
# 13  [Alternant - Data Analyst - statistiques prédi...
# 14                           [Data Scientist - CDI\n]
# 15                   [\nIngénieur MCO CyberSOC F/H\n]
# ...

# %%
df['Intitulé du poste'] = df['Intitulé du poste'].apply(lambda x: ''.join(map(str, x)).replace("\n", ""))
df['Intitulé du poste']
# Out:
# 0                               Data Analyst - Publicité
# 1                                     Data analyst - H/F
# 2                            Customer Data Analyst (H/F)
# 3                                Master Data Analyst H/F
# 4                             Portfolio Data Analyst H/F
#                              ...
# 225                            SAP Fiori Developer (H/F)
# 226             ENGIE Digital - Architecte Données (H/F)
# 227    Quality Assurance - Lead QA - Lead Acceptance H/F
# 228                                       DATA SCIENTIST
# 229                                  Datascientist (H/F)
# Name: Intitulé du poste, Length: 230, dtype: object

# %%
df['Date de publication'] = df['Date de publication'].apply(lambda x: x.replace("\n", "").replace("postée il y a", ""))
df['Date de publication']
# Out:
# 0       21 jours
# 1         1 mois
# 2       27 jours
# 3       21 jours
# 4        3 jours
#          ...
# 225     27 jours
# 226      3 jours
# 227     2 heures
# 228     16 jours
# 229      3 jours
# Name: Date de publication, Length: 230, dtype: object

# %%
df['lieu'] = df['lieu'].apply(lambda x: ''.join(map(str, x)).replace("\n", ""))
df['lieu']
# Out:
# 0                                                Paris
# 1                                    Paris, La Défense
# 2                                                Paris
# 3                                      Moussy-le-Vieux
# 4                                               France
#                             ...
# 225                                         Saint-Ouen
# 226                                              Paris
# 227                               Boulogne-Billancourt
# 228    NEUILLY SUR SEINE38.000,00 € - 50.000,00 € / an
# 229                                         Saint-Ouen
# Name: lieu, Length: 230, dtype: object

# %%
df['competences'] = df['competences'].apply(lambda x: ''.join(map(str, x)).replace("\n", " "))

df['competences']
# Out:
# 0                                 sql  t-sql  outils
# 1           support  outils  agile  design  big data
# 2                crm  data quality  sql  sas  python
# 3                                   si  support  sap
# 4            outils  support  decisionnel  sql  test
#                             ...
# 225           sap  abap  progiciel  système  support
# 226       digital  outils  securité  sécurité  t-sql
# 227               test  serveur  jquery  mobile  tdd
# 228       nosql  unix  java  machine learning  linux
# 229     big data  support  python  réseaux  securité
# Name: competences, Length: 230, dtype: object

# %%
df['Type de poste'] = df['Type de poste'].apply(lambda x: ''.join(map(str, x)).replace("\n", " "))

df['Type de poste']
# Out:
# 0        Sept Lieues SAS Cabinet de recrutement   CDI...
# 1           EDF France Client final   CDI - temps plein
# 2               Hermès Client final   CDI - temps plein
# 3               TEREOS Client final   CDI - temps plein
# 4         Safran-Group Client final   CDI - temps plein
#                              ...
# 225       Groupe ENGIE Client final   CDI - temps plein
# 226       Groupe ENGIE Client final   CDI - temps plein
# 227      Francaise des jeux Client final   CDI - temp...
# 228                      BEEZEN ESN   CDI - temps plein
# 229       Groupe ENGIE Client final   CDI - temps plein
# Name: Type de poste, Length: 230, dtype: object

# %%
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             Data Analyst - Publicité            21 jours
# 1                                   Data analyst - H/F              1 mois
# 2                          Customer Data Analyst (H/F)            27 jours
# 3                              Master Data Analyst H/F            21 jours
# 4                           Portfolio Data Analyst H/F             3 jours
# ..                                                 ...                 ...
# 225                          SAP Fiori Developer (H/F)            27 jours
# 226           ENGIE Digital - Architecte Données (H/F)             3 jours
# 227  Quality Assurance - Lead QA - Lead Acceptance H/F            2 heures
# 228                                     DATA SCIENTIST            16 jours
# 229                                Datascientist (H/F)             3 jours
#
#                                                 lieu  \
# ...

# %%
#df["duree"] = df["Date de publication"].replace(r'^[0-9]+$', "", regex=True)
df["duree"] = df["Date de publication"].str.extract(r'(\d+)(\D+)')[1]
df['duree']
# Out:
# 0        jours
# 1         mois
# 2        jours
# 3        jours
# 4        jours
#         ...
# 225      jours
# 226      jours
# 227     heures
# 228      jours
# 229      jours
# Name: duree, Length: 230, dtype: object

# %%
# Définir la date de référence
datetime_str = '15/01/2023'

datetime_object = datetime.strptime(datetime_str, '%d/%m/%Y')

#print(datetime_object - timedelta(1))



df['nb_jour'] = df['Date de publication'].str.extract(r'(\d+)').fillna(1).astype(int)

df.head(40)
# Out:
#                                     Intitulé du poste Date de publication  \
# 0                            Data Analyst - Publicité            21 jours
# 1                                  Data analyst - H/F              1 mois
# 2                         Customer Data Analyst (H/F)            27 jours
# 3                             Master Data Analyst H/F            21 jours
# 4                          Portfolio Data Analyst H/F             3 jours
# 5                   Data Analyst BO/Qlick Sense (h/f)            15 jours
# 6                     Product Data Analyst - BI - H/F            28 jours
# 7              Data Analyst / Chef de Projet BI (h/f)              1 mois
# 8        Business analyst senior DATA CRM - Paris H/F           12 heures
# 9   Data scientist / Analyst and software developm...            13 jours
# 10       Data Analyst (H/F) – Mobile Gaming - Gaminho            13 jours
# 11  Responsable Analyses et Data Relation Clients ...            14 jours
# ...

# %%
#df['nb_jour_final'] = df.apply(lambda x: x['nb_jour'] * 31 if x['duree'] == 'mois' else 0 if x['duree'] == 'heures' else 1 if pd.isna(x['duree']) else x['nb_jour'] , axis=1)
df.head(40)
# Définir la date de référence
datetime_str = '15/01/2023'

datetime_object = datetime.strptime(datetime_str, '%d/%m/%Y')
# Transformer les valeurs de la colonne 1 en liste
col1_list = df['duree'].tolist()

# Transformer les valeurs de la colonne 2 en liste
col2_list = df['nb_jour'].tolist()
print(col2_list)
print(col1_list)

nb_jour_final = []

# Itérer simultanément sur les deux listes
for value1, value2 in zip(col1_list, col2_list):
    if value1 == 'jours':
        continue
    elif value1 == 'mois':
        value2 = value2 * 31
    elif value1 == 'heures':
        value2 = 0
    elif value1 == 'nan':
        value2 = 1
        
    nb_jour_final.append(value2)


df['nb_jour_final'] = pd.DataFrame(nb_jour_final)

df
# Out:
# [21, 1, 27, 21, 3, 15, 28, 1, 12, 13, 13, 14, 3, 14, 28, 9, 2, 2, 14, 5, 22, 8, 25, 21, 29, 19, 1, 1, 1, 5, 14, 13, 9, 22, 21, 9, 22, 22, 29, 1, 7, 22, 2, 17, 2, 21, 22, 9, 22, 15, 1, 15, 20, 21, 20, 28, 20, 22, 24, 1, 21, 1, 27, 21, 3, 15, 28, 1, 12, 13, 13, 14, 3, 14, 28, 9, 2, 2, 14, 5, 9, 14, 22, 9, 24, 24, 4, 6, 2, 24, 7, 21, 1, 17, 11, 1, 22, 1, 1, 5, 27, 7, 1, 1, 1, 16, 20, 13, 1, 1, 3, 1, 3, 28, 16, 2, 17, 17, 1, 1, 27, 1, 22, 1, 22, 3, 3, 3, 10, 22, 17, 1, 14, 17, 25, 17, 27, 24, 7, 1, 3, 3, 1, 14, 3, 27, 3, 20, 1, 1, 21, 27, 20, 21, 17, 9, 1, 1, 21, 2, 16, 1, 1, 1, 24, 27, 17, 7, 1, 25, 28, 10, 13, 2, 3, 17, 1, 22, 6, 17, 1, 14, 28, 21, 13, 6, 10, 17, 28, 17, 8, 14, 20, 20, 14, 3, 13, 13, 10, 14, 2, 22, 16, 22, 21, 1, 13, 22, 1, 22, 14, 22, 22, 21, 23, 14, 22, 14, 14, 3, 17, 17, 14, 2, 13, 27, 3, 2, 16, 3]
# ...

# %%
"""
# Itérer sur les lignes du DataFrame
for index, row in df.iterrows():
    # Vérifier la valeur de la première colonne
   
    if row['duree'] == 'mois':
        df.at[index, 'nb_jour'] = row['nb_jour'] * 31
    elif row['duree'] == 'nan':
        df.at[index, 'nb_jour'] = 1
    elif row['duree'] == 'heures':
        df.at[index, 'nb_jour'] = 0

df['nb_jour_final'] = df.apply(lambda x: x['nb_jour'] * 31 if x['duree'] == 'mois' else 0 if x['duree'] == 'heures' else 1 if pd.isna(x['duree']) else x['nb_jour'] , axis=1)

df[['nb_jour_final']]= df[['nb_jour_final']].apply(pd.to_numeric)

df[['nb_jour']]= df[['nb_jour']].apply(pd.to_numeric)
df['nb_jour_final'] = df.apply(lambda x: x['nb_jour']*31 if x['duree'] == 'mois' else 0 if x['duree'] == 'heures' else x['nb_jour'], axis=1)


for i in range(df.shape[0]):

    if df.iloc[i]['duree'] == 'mois':
        df.at[i, 'nb_jour'] = df.iloc[i]['nb_jour']*31
    elif df.iloc[i]['duree'] == 'heures':
        df.at[i, 'nb_jour'] = 0


for i in range(df.shape[0]):

    if df.iloc[i]['duree'] == 'mois':
        df.at[i, 'nb_jour'] = df.iloc[i]['nb_jour']*31
    elif df.iloc[i]['duree'] == 'heures':
        df.at[i, 'nb_jour'] = 0
        
# Convertir la colonne 2 en objets timedelta
df['nb_jour'] = pd.to_timedelta(df['nb_jour'])

# Ajouter une nouvelle colonne pour stocker la date 
df['date'] = datetime_object

# Itérer sur la colonne date et soustraire la valeur de la colonne 2
for i in range(df.shape[0]):
    df.at[i, 'date'] = df.iloc[i]['date'] - timedelta(days=df.iloc[i]['nb_jour'])

"""
# Out:
# "\n# Itérer sur les lignes du DataFrame\nfor index, row in df.iterrows():\n    # Vérifier la valeur de la première colonne\n   \n    if row['duree'] == 'mois':\n        df.at[index, 'nb_jour'] = row['nb_jour'] * 31\n    elif row['duree'] == 'nan':\n        df.at[index, 'nb_jour'] = 1\n    elif row['duree'] == 'heures':\n        df.at[index, 'nb_jour'] = 0\n\ndf['nb_jour_final'] = df.apply(lambda x: x['nb_jour'] * 31 if x['duree'] == 'mois' else 0 if x['duree'] == 'heures' else 1 if pd.isna(x['duree']) else x['nb_jour'] , axis=1)\n\ndf[['nb_jour_final']]= df[['nb_jour_final']].apply(pd.to_numeric)\n\ndf[['nb_jour']]= df[['nb_jour']].apply(pd.to_numeric)\ndf['nb_jour_final'] = df.apply(lambda x: x['nb_jour']*31 if x['duree'] == 'mois' else 0 if x['duree'] == 'heures' else x['nb_jour'], axis=1)\n\n\nfor i in range(df.shape[0]):\n\n    if df.iloc[i]['duree'] == 'mois':\n        df.at[i, 'nb_jour'] = df.iloc[i]['nb_jour']*31\n    elif df.iloc[i]['duree'] == 'heures':\n        df.at[i, 'nb
# ...
